# %% [markdown]
# # Boxplots
#
# This notebook contains the code to create boxplots and violin plots in `lets-plot`, using the ["Airlines Delays from 2003-2016"](https://www.kaggle.com/datasets/giovamata/airlinedelaycauses) dataset by [Priank Ravichandar](https://www.kaggle.com/priankravichandar) licensed under [CC0 1.0](https://creativecommons.org/publicdomain/zero/1.0/). This dataset contains the information on flight delays and cancellations in the US airports for the period of 2003-2016.

# %%
import pandas as pd
from lets_plot import *

LetsPlot.setup_html()
# Out:
#             <div id="evq51j"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.0.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("evq51j").appendChild(div);
#                     };
#                     var e = document.getElementById("evq51j");
#                     e.appendChild(script);
#                 })()
#             </script>

# %% [markdown]
# ## Import and process the data
# * Create a date/time variable from the month/year column
# * Remove the first and last years, as they only contain partial records for the year
# * Create a variable which calculates the average delay per flight per airport per month
# * Create a variable which indicates the US region that an airport is located in

# %%
airlines = pd.read_csv("data/airlines.csv")
airlines["Time"] = pd.to_datetime(airlines["TimeLabel"], infer_datetime_format=True)
airlines = airlines[~(airlines["TimeYear"].isin([2003, 2016]))]
airlines["AverageMinutesDelayed"] = airlines["MinutesDelayedTotal"] / airlines["FlightsDelayed"]

airlines["region"] = airlines["AirportCode"].map({
    "ATL": "Southeast",
    "BOS": "Northeast",
    "BWI": "Northeast",
    "CLT": "Southeast",
    "DCA": "Southeast",
    "DEN": "West",
    "DFW": "Southwest",
    "DTW": "Midwest",
    "EWR": "Northeast",
    "FLL": "Southeast",
    "IAD": "Southeast",
    "IAH": "Southwest",
    "JFK": "Northeast",
    "LAS": "West",
    "LAX": "West",
    "LGA": "Northeast",
    "MCO": "Southeast",
    "MDW": "Midwest",
    "MIA": "Southeast",
    "MSP": "Midwest",
    "ORD": "Midwest",
    "PDX": "West",
    "PHL": "Northeast",
    "PHX": "Southwest",
    "SAN": "West",
    "SEA": "West",
    "SFO": "West",
    "SLC": "West",
    "TPA": "Southeast",
})

# %% [markdown]
# ## Boxplot showing distribution of the time a flight is delayed by airport

# %%
(
        ggplot(airlines,
               aes(x="AirportCode", y="AverageMinutesDelayed"))
        + geom_boxplot(fill = "#b3cde3")
        + xlab("Airport code")
        + ylab("Flight delay (minutes)")
        + ggtitle("Distribution of flight delay times in US airports, 2004-2015")
)
# Out:
#    <div id="44crRZ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"AirportCode",
# "y":"AverageMinutesDelayed"
# },
# "data_meta":{
# "series_annotations":[{
# "column":"Time",
# "type":"datetime"
# }]
# },
# "ggtitle":{
# "text":"Distribution of flight delay times in US airports, 2004-2015"
# },
# "kind":"plot",
# "scales":[{
# "name":"Airport code",
# "aesthetic":"x"
# },{
# "name":"Flight delay (minutes)",
# "aesthetic":"y"
# }],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "fill":"#b3cde3",
# "data":{
# "..middle..":[NaN,NaN,57.91533264267129,NaN,56.74757558713685,NaN,NaN,50.14183057263825,NaN,47.770536151088585,50.42124955220747,NaN,52.03427400567914,58.981745269265346,55.728415006709625,66.4847615686681,50.83754612912186,NaN,59.541306719843476,54.97551836589764,60.098123323943284,48.238721059356415,50.202456343358406,58.798585802662885,52.364613183507146,NaN,NaN,49.12936555102715,55.21945962955645,54.74785872450495,NaN,66.36178571230009,49.039187600722826,NaN,57.335304115684096,46.98895776952746,NaN,46.24851204534719,48.74332974266906,NaN,NaN,NaN,NaN,59.30123685960487,47.30872916503638,51.18848572326864],
# "..lower..":[NaN,NaN,54.164210838353966,NaN,52.18706014515587,NaN,NaN,46.43018445012471,NaN,44.00363007421652,46.47274977785615,NaN,48.60496738438627,54.49682787026521,51.45051017825456,60.8020007029297,47.621523985183536,NaN,54.863335228995794,48.866096510603015,53.72149558319609,45.125683785826595,46.7967168450765,54.8822621568861,48.48311117609397,NaN,NaN,45.80715878448454,51.4732041926661,50.057796731375554,NaN,60.79234958532956,46.155293462822925,NaN,52.177191845641694,44.68210184699559,NaN,44.00397259664576,46.28487915021208,NaN,NaN,NaN,NaN,54.12134836278328,45.017263387216076,47.05378509034091],
# "..upper..":[NaN,NaN,62.80234774780884,NaN,61.098095206456776,NaN,NaN,56.17702495943438,NaN,50.87210465286825,55.80695739389141,NaN,56.31945120390452,63.938676281355654,60.249474166461525,72.78866528931273,56.006306018500354,NaN,64.2776549796748,60.95814535141969,66.6472807108397,51.93956490601363,52.57000871706175,64.90415957528768,56.5310029952536,NaN,NaN,55.02720992891104,59.002601906923644,59.2038305614256,NaN,70.8267116949088,51.62738175956163,NaN,60.926657017840526,50.18652773694586,NaN,49.573526450053706,51.625587484893245,NaN,NaN,NaN,NaN,64.47123379218895,53.30114954737083,54.00439074200136],
# "..ymin..":[NaN,NaN,42.53494822485207,NaN,41.605442176870746,NaN,NaN,39.73435655253837,NaN,36.824175824175825,40.3397823458283,NaN,41.5475651189128,45.63745019920319,40.01436910642119,47.54119484576337,40.78490028490028,NaN,45.232804232804234,37.451492537313435,38.819330855018585,38.815184049079754,39.7357120303126,41.39959225280326,41.76949443016281,NaN,NaN,35.938472418670436,41.80509868421053,41.25624752082507,NaN,49.71526677231907,41.76297577854671,NaN,43.60637381567614,38.960508701472556,NaN,37.29626749611197,40.63799283154122,NaN,NaN,NaN,NaN,41.79211229946524,38.70261941448382,40.2127417519909],
# "..ymax..":[NaN,NaN,74.41790373369321,NaN,72.41098169717138,NaN,NaN,70.71125611745514,NaN,60.75591615956728,68.51289566236811,NaN,66.861931699141,77.19758848697005,70.11111111111111,89.23414071510958,63.98778920308483,NaN,75.99454545454546,77.3198717948718,81.6861985472155,61.716981132075475,61.063262764632626,78.36315789473684,66.79847908745248,NaN,NaN,65.00227790432803,69.97960484384959,71.44705603038936,NaN,85.49167087329631,59.542204568023834,NaN,73.3536905207943,57.97838345864662,NaN,56.49815770081061,59.58447780261897,NaN,NaN,NaN,NaN,78.40445344129554,63.45335820895522,64.07804522246535],
# "AirportCode":["ATL","ATL","ATL","BOS","BOS","BWI","BWI","BWI","CLT","CLT","DCA","DEN","DEN","DFW","DTW","EWR","FLL","IAD","IAD","IAH","JFK","LAS","LAX","LGA","MCO","MDW","MDW","MDW","MIA","MSP","ORD","ORD","PDX","PHL","PHL","PHX","SAN","SAN","SEA","SFO","SFO","SFO","SFO","SFO","SLC","TPA"],
# "AverageMinutesDelayed":[83.21635937659163,79.56010230179028,NaN,74.79181494661921,NaN,71.04351610095735,75.65855940130963,NaN,63.3445945945946,NaN,NaN,71.37257617728532,NaN,NaN,NaN,NaN,NaN,80.54981718464352,NaN,NaN,NaN,NaN,NaN,NaN,NaN,72.42625523012552,72.20213903743316,NaN,NaN,NaN,91.02000845427645,NaN,NaN,74.38438210765732,NaN,NaN,58.45253863134658,NaN,NaN,81.04404599493276,82.21325597749649,80.92256598496766,80.53393057110863,NaN,NaN,NaN]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("44crRZ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Boxplot showing distribution of the time a flight is delayed by airport, by US region

# %%
(
        ggplot(airlines,
               aes(x="AirportCode", y="AverageMinutesDelayed", fill = "region"))
        + geom_boxplot()
        + xlab("Airport code")
        + ylab("Flight delay (minutes)")
        + ggtitle("Distribution of flight delay times in US airports, 2004-2015")
        + scale_fill_brewer(type="qual", palette="Pastel1", name="US region")
)
# Out:
#    <div id="mtEqwT"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"AirportCode",
# "y":"AverageMinutesDelayed",
# "fill":"region"
# },
# "data_meta":{
# "series_annotations":[{
# "column":"Time",
# "..ymax..":[NaN,NaN,74.41790373369321,NaN,60.75591615956728,68.51289566236811,63.98778920308483,NaN,75.99454545454546,66.79847908745248,69.97960484384959,64.07804522246535,NaN,72.41098169717138,NaN,NaN,70.71125611745514,89.23414071510958,81.6861985472155,78.36315789473684,NaN,73.3536905207943,NaN,66.861931699141,61.716981132075475,61.063262764632626,59.542204568023834,NaN,56.49815770081061,59.58447780261897,NaN,NaN,NaN,NaN,78.40445344129554,63.45335820895522,77.19758848697005,77.3198717948718,57.97838345864662,70.11111111111111,NaN,NaN,65.00227790432803,71.44705603038936,NaN,85.49167087329631],
# "AirportCode":["ATL","ATL","ATL","CLT","CLT","DCA","FLL","IAD","IAD","MCO","MIA","TPA","BOS","BOS","BWI","BWI","BWI","EWR","JFK","LGA","PHL","PHL","DEN","DEN","LAS","LAX","PDX","SAN","SAN","SEA","SFO","SFO","SFO","SFO","SFO","SLC","DFW","IAH","PHX","DTW","MDW","MDW","MDW","MSP","ORD","ORD"],
# "AverageMinutesDelayed":[83.21635937659163,79.56010230179028,NaN,63.3445945945946,NaN,NaN,NaN,80.54981718464352,NaN,NaN,NaN,NaN,74.79181494661921,NaN,71.04351610095735,75.65855940130963,NaN,NaN,NaN,NaN,74.38438210765732,NaN,71.37257617728532,NaN,NaN,NaN,NaN,58.45253863134658,NaN,NaN,81.04404599493276,82.21325597749649,80.92256598496766,80.53393057110863,NaN,NaN,NaN,NaN,NaN,NaN,72.42625523012552,72.20213903743316,NaN,NaN,91.02000845427645,NaN],
# "region":["Southeast","Southeast","Southeast","Southeast","Southeast","Southeast","Southeast","Southeast","Southeast","Southeast","Southeast","Southeast","Northeast","Northeast","Northeast","Northeast","Northeast","Northeast","Northeast","Northeast","Northeast","Northeast","West","West","West","West","West","West","West","West","West","West","West","West","West","West","Southwest","Southwest","Southwest","Midwest","Midwest","Midwest","Midwest","Midwest","Midwest","Midwest"]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("mtEqwT");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Violin plot showing distribution of the time a flight is delayed by airport

# %%
(
        ggplot(airlines,
               aes(x="AirportCode", y="AverageMinutesDelayed", fill = "region"))
        + geom_violin()
        + xlab("Airport code")
        + ylab("Flight delay (minutes)")
        + ggtitle("Distribution of flight delay times in US airports, 2004-2015")
        + scale_fill_brewer(type="qual", palette="Pastel1", name="US region")
)
# Out:
#    <div id="62mY41"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"AirportCode",
# "y":"AverageMinutesDelayed",
# "fill":"region"
# },
# "data_meta":{
# "series_annotations":[{
# "column":"Time",
