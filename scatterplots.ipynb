# %% [markdown]
# # Scatterplots
#
# This notebook contains the code to create scatterplots and weighted scatterplots in `lets-plot`, using the ["Airlines Delays from 2003-2016"](https://www.kaggle.com/datasets/giovamata/airlinedelaycauses) dataset by [Priank Ravichandar](https://www.kaggle.com/priankravichandar) licensed under [CC0 1.0](https://creativecommons.org/publicdomain/zero/1.0/). This dataset contains the information on flight delays and cancellations in the US airports for the period of 2003-2016.

# %%
import pandas as pd
from lets_plot import *

LetsPlot.setup_html()
# Out:
#             <div id="BGG2Fd"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.0.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("BGG2Fd").appendChild(div);
#                     };
#                     var e = document.getElementById("BGG2Fd");
#                     e.appendChild(script);
#                 })()
#             </script>

# %% [markdown]
# ## Import and process the data
# * Create a date/time variable from the month/year column
# * Remove the first and last years, as they only contain partial records for the year

# %%
airlines = pd.read_csv("data/airlines.csv")
airlines["Time"] = pd.to_datetime(airlines["TimeLabel"], infer_datetime_format=True)
airlines = airlines[~(airlines["TimeYear"].isin([2003, 2016]))]

# %% [markdown]
# ## Scatterplot showing relationship between delays from weather and delays from late aircraft

# %%
(
        ggplot(airlines, aes(x="NumDelaysWeather", y="NumDelaysLateAircraft"))
        + geom_point(color = "#fbb4ae")
        + xlab("Number of delays from weather")
        + ylab("Number of delays from late aircraft")
        + ggtitle("Relationship between delays in US airports, 2004-2015")
)
# Out:
#    <div id="n7nkbJ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "NumDelaysLateAircraft":[1265.0,699.0,611.0,498.0,343.0,638.0,1439.0,542.0,642.0,376.0,505.0,637.0,501.0,908.0,900.0,568.0,518.0,560.0,285.0,583.0,2501.0,315.0,601.0,786.0,419.0,722.0,553.0,593.0,399.0,1579.0,484.0,543.0,422.0,265.0,467.0,1437.0,414.0,555.0,418.0,444.0,680.0,288.0,921.0,884.0,496.0,492.0,470.0,261.0,527.0,2205.0,263.0,518.0,874.0,416.0,534.0,388.0,492.0,437.0,912.0,578.0,589.0,437.0,296.0,412.0,943.0,504.0,622.0,377.0,462.0,611.0,350.0,929.0,877.0,464.0,490.0,529.0,216.0,527.0,2491.0,265.0,542.0,817.0,392.0,554.0,364.0,325.0,385.0,924.0,529.0,648.0,388.0,285.0,364.0,777.0,383.0,655.0,374.0,430.0,660.0,297.0,875.0,813.0,451.0,513.0,479.0,160.0,300.0,1483.0,233.0,448.0,782.0,
514.0,1040.0,758.0,751.0,1313.0,1233.0,588.0,855.0,674.0,451.0,817.0,2329.0,522.0,930.0,1086.0,604.0,1342.0,737.0,642.0,561.0,2557.0,974.0,1083.0,867.0,771.0,1141.0,3009.0,924.0,1234.0,696.0,1170.0,1584.0,1165.0,1545.0,1443.0,740.0,1043.0,879.0,492.0,992.0,2241.0,501.0,1167.0,1254.0,675.0,1182.0,723.0,733.0,759.0,2113.0,688.0,908.0,585.0,489.0,788.0,2313.0,957.0,1116.0,485.0,763.0,1129.0,801.0,1293.0,1155.0,626.0,768.0,661.0,381.0,1036.0,1663.0,456.0,861.0,1087.0,571.0,982.0,683.0,684.0,564.0,977.0,457.0,469.0,284.0,293.0,461.0,1118.0,549.0,588.0,184.0,357.0,518.0,328.0,947.0,803.0,375.0,323.0,419.0,172.0,530.0,1262.0,293.0,426.0,744.0,419.0,609.0,417.0,432.0,249.0,1402.0,586.0,703.0,434.0,375.0,590.0,1195.0,498.0,720.0,309.0,479.0,604.0,453.0,1168.0,1041.0,394.0,553.0,558.0,221.0,477.0,1101.0,391.0,559.0,1002.0,495.0,557.0,516.0,449.0,383.0,1260.0,609.0,621.0,345.0,386. ...

# %% [markdown]
# ## Scatterplot showing relationship between delays from weather and delays from late aircraft by airport

# %%
(
        ggplot(airlines[airlines["AirportCode"].isin(["LGA", "LAS"])],
               aes(x="NumDelaysWeather", y="NumDelaysLateAircraft", color="AirportCode"))
        + geom_point()
        + xlab("Number of delays from weather")
        + ylab("Number of delays from late aircraft")
        + scale_color_brewer(type="qual", palette="Pastel1", name="Airport code")
        + ggtitle("Relationship between delays for LAS and LGA, 2004-2015")
)
# Out:
#    <div id="lxd7N1"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "AirportCode":["LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","LGA","LAS","L
# "NumDelaysWeather":[78.0,213.0,159.0,116.0,56.0,127.0,74.0,118.0,50.0,175.0,69.0,154.0,53.0,192.0,67.0,177.0,34.0,114.0,101.0,103.0,117.0,137.0,100.0,203.0,149.0,208.0,120.0,171.0,48.0,248.0,41.0,106.0,31.0,126.0,60.0,161.0,116.0,195.0,98.0,153.0,39.0,90.0,107.0,172.0,24.0,165.0,65.0,194.0,85.0,178.0,64.0,145.0,103.0,121.0,51.0,115.0,72.0,201.0,73.0,210.0,116.0,184.0,84.0,171.0,71.0,161.0,78.0,178.0,45.0,181.0,88.0,149.0,88.0,181.0,107.0,221.0,52.0,125.0,50.0,160.0,59.0,140.0,92.0,168.0,106.0,189.0,87.0,169.0,26.0,86.0,33.0,132.0,59.0,111.0,86.0,195.0,108.0,118.0,132.0,178.0,58.0,160.0,17.0,137.0,47.0,128.0,82.0,202.0,70.0,174.0,99.0,130.0,19.0,94.0,20.0,69.0,54.0,83.0,146.0,185.0,77.0,151.0,36.0,104.0,81.0,103.0,55.0,120.0,34.0,161.0,66.0,187.0,65.0,140.0,47.0,101.0,12.0,45.0,33.0,88.0,7.0,60.0,88.0,129.0,118.0,81.0,46.0,85.0,57.0,129.0,39.0,32.0,43.0,74.0,52.0,76.0,52.0,91.0,35.0,59.0,28.0,57.0,33.0,42.0,19.0,37.0,87.0,68.0,64.0,67.0,53.0,90.0,31.0,52.0,38.0,96.0,63.0,92.0,46.0,90.0,53.0,67.0,77.0,85.0,33.0,43.0,21.0,28.0,22.0,37.0,20.0,24.0,48.0,53.0,13.0,16.0,49.0,41.0,23.0,28.0,47.0,87.0,39.0,63.0,75.0,96.0,62.0,65.0,49.0,50.0,30.0,45.0,20.0,25.0,62.0,48.0,28.0,58.0,27.0,58.0,28.0,60.0,38.0,69.0,61.0,66.0,66.0,121.0,77.0,98.0,68.0,58.0,63.0,53.0,52.0,41.0,69.0,47.0,67.0,103.0,97.0,151.0,99.0,70.0,26.0,48.0,29.0,57.0,43.0,94.0,58.0,114.0,83.0,92.0,72.0,78.0,66.0,43.0,23.0,47.0,37.0,65.0,85.0,55.0,72.0,85.0,90.0,145.0,60.0,85.0,49.0,59.0,76.0,78.0,65.0,121.0,71.0,90.0,79.0,95.0,38.0,74.0,85.0,36.0,50.0,45.0,42.0,75.0]
# },
# "mapping":{
# "x":"NumDelaysWeather",
# "y":"NumDelaysLateAircraft",
# "color":"AirportCode"
# },
# "data_meta":{
# "series_annotations":[{
# "column":"Time",
# "type":"datetime"
# }]
# },
# "ggtitle":{
# "text":"Relationship between delays for LAS and LGA, 2004-2015"
# },
# "kind":"plot",
# "scales":[{
# "name":"Number of delays from weather",
# "aesthetic":"x"
# },{
# "name":"Number of delays from late aircraft",
# "aesthetic":"y"
# },{
# "name":"Airport code",
# "aesthetic":"color",
# "type":"qual",
# "palette":"Pastel1",
# "scale_mapper_kind":"color_brewer"
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("lxd7N1");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Scatterplot showing relationship between delays from weather and delays from late aircraft by airport size

# %%
(
        ggplot(airlines[(airlines["TimeLabel"].isin(["2013/12", "2014/1", "2014/2", "2014/12", "2015/1", "2015/2"]))],
               aes(x="NumDelaysWeather", y="NumDelaysLateAircraft", size="FlightsTotal"))
        + geom_point(color = "#b3cde3")
        + xlab("Number of delays from weather")
        + ylab("Number of delays from late aircraft")
        + ggtitle("Relationship between delays by total flights, winters 2013/2014")
        + scale_size(name="Total flights")
)
# Out:
#    <div id="I3eKb8"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "NumDelaysLateAircraft":[2782.0,912.0,1340.0,959.0,412.0,2639.0,2147.0,1079.0,1016.0,657.0,634.0,1471.0,908.0,1624.0,1943.0,848.0,989.0,1283.0,473.0,1240.0,2777.0,553.0,439.0,1405.0,804.0,602.0,1137.0,893.0,749.0,1476.0,602.0,648.0,370.0,352.0,1822.0,3081.0,491.0,658.0,355.0,360.0,1133.0,511.0,1255.0,1918.0,530.0,669.0,644.0,435.0,498.0,2097.0,432.0,301.0,1174.0,828.0,734.0,1468.0,644.0,401.0],
# "NumDelaysWeather":[210.0,75.0,53.0,85.0,65.0,144.0,249.0,113.0,77.0,55.0,38.0,136.0,67.0,67.0,194.0,103.0,70.0,74.0,108.0,141.0,224.0,40.0,61.0,80.0,42.0,84.0,157.0,109.0,51.0,50.0,31.0,11.0,7.0,18.0,103.0,114.0,23.0,32.0,11.0,10.0,45.0,33.0,85.0,99.0,55.0,11.0,16.0,18.0,26.0,56.0,12.0,24.0,18.0,17.0,29.0,150.0,28.0,17.0],
# "FlightsTotal":[31894.0,8890.0,7902.0,12837.0,5779.0,19028.0,23763.0,11927.0,9913.0,5881.0,5789.0,14852.0,9151.0,11111.0,19060.0,9064.0,9630.0,7252.0,7489.0,11567.0,23086.0,4726.0,6374.0,14681.0,6243.0,8351.0,13809.0,8737.0,5663.0,30000.0,8872.0,7382.0,9506.0,6460.0,18206.0,23058.0,8696.0,9140.0,6034.0,4320.0,14143.0,8590.0,10750.0,17822.0,9217.0,9757.0,7189.0,6888.0,8424.0,23484.0,3896.0,5729.0,13298.0,6339.0,8991.0,13827.0,8825.0,5776.0]
# },
# "mapping":{
# "x":"NumDelaysWeather",
# "y":"NumDelaysLateAircraft",
# "size":"FlightsTotal"
# },
# "data_meta":{
# "series_annotations":[{
# "column":"Time",
# "type":"datetime"
# }]
# },
# "ggtitle":{
# "text":"Relationship between delays by total flights, winters 2013/2014"
# },
# "kind":"plot",
# "scales":[{
# "name":"Number of delays from weather",
# "aesthetic":"x"
# },{
# "name":"Number of delays from late aircraft",
# "aesthetic":"y"
# },{
# "name":"Total flights",
# "aesthetic":"size"
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"#b3cde3",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("I3eKb8");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
